# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.189  Python-3.10.10 torch-1.12.0+cpu CPU (Intel Core(TM) i5-1035G1 1.00GHz)
# Setup complete  (8 CPUs, 7.8 GB RAM, 36.5/51.1 GB disk)

# %%
import cv2
import torch
import numpy as np
from ultralytics import YOLO

video_path ="exercise 1\Entrance test\Task 1\Videos\Video 3.mp4"


cap = cv2.VideoCapture(video_path)

model = YOLO('yolov8n.pt')

x_line=600

while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()
    width = int(cap.get(3))
    height = int(cap.get(4))

    if success:
        
        # Run YOLOv8 inference on the frame
        resized_frame = cv2.resize(frame, (1280, 720), interpolation=cv2.INTER_LINEAR)
        cv2.line(resized_frame, (0, x_line), (width, x_line), (255, 0, 0), 10)

        # Visualize the results on the frame
        results = model(resized_frame, conf=0.9, )
        
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    else:
        # Break the loop if the end of the video is reached
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
# 0: 384x640 3 persons, 303.3ms
# Speed: 9.0ms preprocess, 303.3ms inference, 20.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 197.7ms
# Speed: 4.0ms preprocess, 197.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 155.0ms
# Speed: 3.0ms preprocess, 155.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 155.0ms
# Speed: 4.0ms preprocess, 155.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 147.0ms
# Speed: 6.0ms preprocess, 147.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 169.0ms
# Speed: 3.0ms preprocess, 169.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 149.0ms
# Speed: 6.0ms preprocess, 149.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 156.0ms
# Speed: 5.0ms preprocess, 156.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 158.0ms
# Speed: 3.0ms preprocess, 158.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 212.0ms
# Speed: 3.0ms preprocess, 212.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 297.0ms
# Speed: 6.0ms preprocess, 297.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 175.0ms
# Speed: 5.0ms preprocess, 175.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 199.0ms
# Speed: 6.0ms preprocess, 199.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 209.0ms
# Speed: 19.0ms preprocess, 209.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 196.0ms
# Speed: 4.0ms preprocess, 196.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 182.0ms
# Speed: 5.0ms preprocess, 182.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 217.0ms
# Speed: 3.0ms preprocess, 217.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 186.0ms
# Speed: 5.0ms preprocess, 186.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 183.0ms
# Speed: 7.0ms preprocess, 183.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 210.0ms
# Speed: 4.0ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 161.0ms
# Speed: 4.0ms preprocess, 161.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 260.0ms
# Speed: 5.0ms preprocess, 260.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 266.0ms
# Speed: 8.0ms preprocess, 266.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 172.0ms
# Speed: 3.0ms preprocess, 172.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 189.0ms
# Speed: 6.0ms preprocess, 189.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 231.0ms
# Speed: 17.0ms preprocess, 231.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 216.0ms
# Speed: 5.0ms preprocess, 216.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 181.0ms
# Speed: 5.0ms preprocess, 181.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 198.0ms
# Speed: 7.0ms preprocess, 198.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 175.0ms
# Speed: 3.0ms preprocess, 175.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 178.0ms
# Speed: 3.0ms preprocess, 178.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 193.0ms
# Speed: 3.0ms preprocess, 193.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 256.0ms
# Speed: 6.0ms preprocess, 256.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 163.0ms
# Speed: 5.0ms preprocess, 163.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons,
0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 249.0ms
# Speed: 4.0ms preprocess, 249.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 206.0ms
# Speed: 4.0ms preprocess, 206.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 204.0ms
# Speed: 6.0ms preprocess, 204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 207.0ms
# Speed: 4.0ms preprocess, 207.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 2 line 2
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=24'>25</a> cv2.line(resized_frame, (0, x_line), (width, x_line), (255, 0, 0), 10)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=26'>27</a> # Visualize the results on the frame
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=27'>28</a> results = model(resized_frame, conf=0.6,classes=0)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=29'>30</a> annotated_frame = results[0].plot()
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=31'>32</a> # Display the annotated frame
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\model.py:95, in Model.__call__(self, source, stream, **kwargs)
#      93 def __call__(self, source=None, stream=False, **kwargs):
#      94     """Calls the 'predict' function with given arguments to perform object detection."""
# ---> 95     return self.predict(source, stream, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\model.py:235, in Model.predict(self, source, stream, predictor, **kwargs)
#     233 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     234     self.predictor.set_prompts(prompts)
# --> 235 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\predictor.py:194, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     192     return self.stream_inference(source, model, *args, **kwargs)
#     193 else:
# --> 194     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\autograd\grad_mode.py:43, in _DecoratorContextManager._wrap_generator.<locals>.generator_context(*args, **kwargs)
#      40 try:
#      41     # Issuing `None` to a generator fires it up
#      42     with self.clone():
# ---> 43         response = gen.send(None)
#      45     while True:
#      46         try:
#      47             # Forward the response to our caller and get its next request
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\predictor.py:253, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     251 # Inference
#     252 with profilers[1]:
# --> 253     preds = self.inference(im, *args, **kwargs)
#     255 # Postprocess
#     256 with profilers[2]:
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\predictor.py:133, in BasePredictor.inference(self, im, *args, **kwargs)
#     130 def inference(self, im, *args, **kwargs):
#     131     visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     132                                mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 133     return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\autobackend.py:339, in AutoBackend.forward(self, im, augment, visualize)
#     336     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     338 if self.pt or self.nn_module:  # PyTorch
# --> 339     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     340 elif self.jit:  # TorchScript
#     341     y = self.model(im)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\modules\head.py:47, in Detect.forward(self, x)
#      45 shape = x[0].shape  # BCHW
#      46 for i in range(self.nl):
# ---> 47     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      48 if self.training:
#      49     return x
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\container.py:139, in Sequential.forward(self, input)
#     137 def forward(self, input):
#     138     for module in self:
# --> 139         input = module(input)
#     140     return input
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\modules\conv.py:42, in Conv.forward_fuse(self, x)
#      40 def forward_fuse(self, x):
#      41     """Perform transposed convolution of 2D data."""
# ---> 42     return self.act(self.conv(x))
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\conv.py:457, in Conv2d.forward(self, input)
#     456 def forward(self, input: Tensor) -> Tensor:
# --> 457     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\nn\modules\conv.py:453, in Conv2d._conv_forward(self, input, weight, bias)
#     449 if self.padding_mode != 'zeros':
#     450     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     451                     weight, bias, self.stride,
#     452                     _pair(0), self.dilation, self.groups)
# --> 453 return F.conv2d(input, weight, bias, self.stride,
#     454                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %% [markdown]
# @software{yolov8_ultralytics,
#   author = {Glenn Jocher and Ayush Chaurasia and Jing Qiu},
#   title = {Ultralytics YOLOv8},
#   version = {8.0.0},
#   year = {2023},
#   url = {https://github.com/ultralytics/ultralytics},
#   orcid = {0000-0001-5950-6979, 0000-0002-7603-6750, 0000-0003-3783-7069},
#   license = {AGPL-3.0}
# }
